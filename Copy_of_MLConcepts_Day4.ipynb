# %% [markdown]
# <a href="https://colab.research.google.com/github/sultan2003-del/Bayes-labs-assignments/blob/main/Copy_of_MLConcepts_Day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### **Introduction**

# %% [markdown]
# Clustering and dimensionality reduction are fundamental techniques in machine learning, widely used in applications such as customer segmentation, image compression, anomaly detection, and feature engineering.
#
# - **K-Means Clustering** is an unsupervised learning algorithm that groups data points into \( K \) clusters based on similarity.
# - **Principal Component Analysis (PCA)** reduces the dimensionality of data while preserving its variance, making it easier to visualize and analyze.

# %% [markdown]
# #### **Our Use**

# %%
# @title
# !pip install faker
# Out:
# Collecting faker
#   Downloading Faker-36.1.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from faker) (2025.1)
# Downloading Faker-36.1.1-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 7.0 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-36.1.1

# %%
# @title
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from faker import Faker
import random

fake = Faker()
n_samples = 10000

# Generate synthetic customer data
data = {
    "CustomerID": [fake.uuid4() for _ in range(n_samples)],
    "Age": np.random.randint(18, 70, n_samples),
    "Gender": np.random.choice(["Male", "Female"], n_samples),
    "Annual_Income": np.random.randint(20000, 150000, n_samples),
    "Spending_Score": np.random.randint(1, 100, n_samples),
    "Purchase_Frequency": np.random.randint(1, 20, n_samples),
    "Total_Transactions": np.random.randint(5, 100, n_samples),
    "Last_Purchase_Amount": np.random.uniform(10, 1000, n_samples),
    "Preferred_Category": np.random.choice(["Electronics", "Fashion", "Groceries", "Furniture", "Sports"], n_samples)
}

df = pd.DataFrame(data)
df.to_csv('synthetic_customer_data.csv', index=False)
df.head()
# Out:
#                              CustomerID  Age  Gender  Annual_Income  \
# 0  6a1b89ab-31cf-4734-a1c1-081a8ed50785   51    Male         136991
# 1  ea5ff770-a059-418f-ac29-cc0be87a72c0   64  Female          86895
# 2  e22d5dac-7033-41f4-8fb9-b9dc488575ec   68    Male         109505
# 3  962460fb-ac85-4278-a11f-4e52bb158582   35  Female          85074
# 4  1c9f98b3-54a4-476f-a691-abb0c78fcd38   66    Male         103461
#
#    Spending_Score  Purchase_Frequency  Total_Transactions  \
# 0              47                  13                  69
# 1              21                  11                  79
# 2              16                   5                  16
# 3              31                  13                  62
# 4               3                   6                  26
#
#    Last_Purchase_Amount Preferred_Category
# 0            725.577515            Fashion
# 1            919.891999          Furniture
# 2            771.372878          Groceries
# 3             18.920011          Furniture
# 4            781.490201          Furniture

# %% [markdown]
# ## **Section 1: K-Means Clustering**

# %% [markdown]
# #### **Understanding K-Means Clustering**
# ---
# K-Means is an iterative clustering algorithm that partitions data into \( K \) distinct, non-overlapping clusters.

# %% [markdown]
# #### **Mathematical Formulation**
# ---
# The goal is to minimize intra-cluster variance:
# $$
# J = \sum_{i=1}^{k} \sum_{x ∈ C_i} || x - \mu_i ||^2
# $$
#
# where:
# - $C_i$ is cluster $i$
# - $\mu_i$ is the centroid of $C_i$
# - $|| x - \mu_i ||^2$ is the squared Euclidean distance

# %% [markdown]
# #### **Real-World Example: Customer Segmentation**
# ---
# Imagine a retail company wants to group customers based on spending habits. **K-Means** helps by clustering similar customers, enabling targeted marketing.

# %% [markdown]
# #### **K-Means Implementation**

# %%
# Load dataset

df = pd.read_csv('synthetic_customer_data.csv')
X = df.drop(columns=["CustomerID", "Gender", "Preferred_Category"])

# %%
# Standardize features

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Apply K-Means

kmeans = KMeans(n_clusters=5, random_state=42)
df['KMeans_Cluster'] = kmeans.fit_predict(X_scaled)

# %%
# Interactive Cluster Visualization

# Reduce dimensions for visualization
pca = PCA(n_components=5)
X_pca = pca.fit_transform(X_scaled)
df['PCA_1'], df['PCA_2'] = X_pca[:, 0], X_pca[:, 1]

fig = px.scatter(df, x='PCA_1', y='PCA_2', color=df['KMeans_Cluster'].astype(str), title="K-Means Clustering Visualization",
                 labels={'color': 'Cluster'}, opacity=0.8)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="74fc8591-d577-44e0-b64d-1a8acd219df5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74fc8591-d577-44e0-b64d-1a8acd219df5")) {                    Plotly.newPlot(                        "74fc8591-d577-44e0-b64d-1a8acd219df5",                        [{"hovertemplate":"Cluster=4\u003cbr\u003ePCA_1=%{x}\u003cbr\u003ePCA_2=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"4","marker":{"color":"#636efa","opacity":0.8,"symbol":"circle"},"mode":"markers","name":"4","showlegend":true,"x":[-0.7686266510721852,-0.5472674561514329,-0.43235048814729266,0.6708305121994258,0.67107161488375,-1.2932560404369666,-0.8022194512455193,-0.3942731144935229,0.6079214414899731,0.10844160337345762,1.6692715163023741,0.06919908704899143,-0.4369949219189032,-1.2083872988763837,-0.23698546363349313,0.5042011543342991,0.35731028164853057,0.9782543348454982,0.8353053875726903,-0.26676608034004246,-0.47392201834132586,-0.3092278768070481,0.7077901489316186,-0.3599124445236838,-1.949934959128061,-0.7301146937962616,-1.127585162961081,-0.08508087703395951,-0.10998425793219338,-0.15171616216702266,0.466720233916068,-0.24219700615224252,-1.9400615663169432,-0.7108713713118326,1.768528728056192,-0.26963344255400934,0.8645360068033187,-0.6454738753752494,-0.7709081275242678,0.9370673647979249,0.45163539494711463,-1.4943530826889604,-1.0093074190169473,-1.2780811780545225,0.2595077578752096,0.4464514603521074,0.6446098106486396,-0.47823264430693313,-0.43240511032445383,0.6370089878263482,-0.8675487192617926,0.5079749285857139,-0.04971967290472204,-0.7409908231139434,0.736858017660816,0.4958621756838462,0.7528527039962734,0.46605969535012604,-0.24836360438529495,0.6091241342362438,-0.8885418855348268,-0.16356396731441186,0.40680303837635823,-0.40634468758217324,-0.9553620214185818,-1.6769602212068029,0.22498835203544731,-0.08219317759987249,-2.0776056402103737,-0.9059694275588702,0.8557340570708717,-0.3647182964677389,-0.8008953072717181,-1.5470371630829796,-1.2393719255267048,1.0364505190021678,0.5748934001410956,1.0454067450678726,0.7428255480888522,0.03967850675441413,0.6241847829951347,1.243380073329566,-0.2318245759976567,0.10529473068135867,-0.1836296569951128,-0.8442264140682143,0.5569104046132903,-0.08996672266388625,0.19968759482509033,-1.005744629959683,0.6624481056167586,0.20203697292865175,-0.7279380294343136,-0.9689928161153456,1.172437976090257,-1.598716845367727,-0.7602978092338352,-0.7168512960350576,0.4768764297728932,-0.16881982357358225,-0.6726251875707208,0.9927581306347665,-1.1281021942466556,0.7436943565063705,1.0740824994342077,0.049720472233078454,-0.5884522145327964,0.42032288203730345,0.2481913695843355,-0.7531128809739539,0.8058985520405352,0.9505370927162513,0.2677247421122007,-0.15775350904503582,0.2933977631181685,-0.06881388543130866,-0.6889782646202065,-0.0521915302001834,-0.27349420084573484,0.3227562949424025,-0.7234221307295464,0.14921552055921428,0.6328958223606511,1.0544872909340737,0.14052491632900946,0.22497208467750854,-0.6657429873921894,0.28605703157136464,-1.6089261452184302,0.39580139739294273,-0.3075294279104659,-0.29406365199697887,1.215137121828906,0.4653419280011999,0.21809679540390478,0.7890532228108869,0.0896970351146478,0.30337521357383124,-1.2962749302577308,0.8590431588896732,0.42075831728853763,-0.8165217008339168,-0.24060953390311215,1.463213490700806,-0.3051881517917985,-0.1221631924132135,0.607370622019111,-0.6976054439702015,-0.9604278530215512,-0.06995936186151615,-1.2600776516588814,-0.8335512058846746,0.3369854442740482,1.0308971417746768,1.28861639359625,-2.233579996693079,-0.171164654973143,0.1962184558585052,-0.252393303167521,-0.8268657805269919,-1.5647220195963527,0.321198753281865 ...

# %% [markdown]
# ## **Section 2: Principal Component Analysis (PCA)**

# %% [markdown]
# #### **Understanding PCA**
# ---
# Principal Component Analysis (PCA) is a statistical technique used to reduce the dimensionality of data while preserving variance.

# %% [markdown]
# #### **Mathematical Formulation**
# ---
#
# - Compute the covariance matrix:
# $$
# σ = \frac{1}{n} ∑_{i=1}^{n} (x_i - \bar{x})(x_i - \bar{x})^T
# $$
# - Compute eigenvalues and eigenvectors:
# $$
# σ v = λ v
# $$
# Where:
#   - $v$ are eigenvectors (principal components)
#   - $λ$ are eigenvalues (variance explained)

# %% [markdown]
# #### **Real-World Example: Image Compression**
# ---
# In facial recognition systems, PCA reduces high-dimensional image data, retaining only the most important features for classification.

# %% [markdown]
# #### **PCA Implementation**

# %%
# Load dataset

df = pd.read_csv('synthetic_customer_data.csv')
X = df.drop(columns=["CustomerID", "Gender", "Preferred_Category"])

# %%
# Standardize features

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Apply PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)
df_pca = pd.DataFrame(X_pca, columns=[f'PC_{i+1}' for i in range(2)])
explained_variance = pca.explained_variance_ratio_

# %%
# Explained Variance Visualization

plt.figure(figsize=(8, 6))
plt.bar(range(1, len(explained_variance)+1), explained_variance, alpha=0.7)
plt.xlabel("Principal Components")
plt.ylabel("Explained Variance Ratio")
plt.title("PCA - Explained Variance")
plt.show()

# %% [markdown]
# ## **Section 3: Assignments**

# %% [markdown]
# #### **Beginner Assignment**
# - Run K-Means with different values of \( K \) and observe changes in clusters.
# - Modify PCA components and analyze variance explained.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler


data = pd.read_csv("StudentStudyHours.csv")


X = data[["StudyHours"]]


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


def run_kmeans(X, max_k=10):
    wcss = []
    for k in range(1, max_k + 1):
        model = KMeans(n_clusters=k, random_state=42, n_init=10)
        model.fit(X)
        wcss.append(model.inertia_)


    plt.plot(range(1, max_k + 1), wcss, marker='o')
    plt.xlabel("Number of Clusters (K)")
    plt.ylabel("WCSS")
    plt.title("Elbow Method for K Selection")
    plt.show()

run_kmeans(X_scaled)

def analyze_pca(X, components=2):
    pca = PCA(n_components=components)
    X_transformed = pca.fit_transform(X)
    explained_variance = np.sum(pca.explained_variance_ratio_)
    print(f"Explained variance with {components} components: {explained_variance:.2f}")
    return X_transformed

X_pca = analyze_pca(X_scaled)

# %% [markdown]
# #### **Advanced Assignment**
# - Apply PCA on a real-world dataset (e.g., MNIST) and compare clustering before/after PCA.
# - Implement spectral clustering and compare its performance with K-Means

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import fetch_openml


print("Loading MNIST dataset...")
mnist = fetch_openml("mnist_784", version=1, parser="auto")
X_mnist = mnist.data / 255.0


def run_kmeans(X, n_clusters=10):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
    kmeans.fit(X)
    return kmeans.inertia_


print("Running K-Means before PCA...")
kmeans_before_pca = run_kmeans(X_mnist)
print("WCSS Before PCA:", kmeans_before_pca)


print("Applying PCA...")
pca = PCA(n_components=50)
X_mnist_pca = pca.fit_transform(X_mnist)
explained_variance = np.sum(pca.explained_variance_ratio_)
print(f"Explained variance with 50 components: {explained_variance:.2f}")


print("Running K-Means after PCA...")
kmeans_after_pca = run_kmeans(X_mnist_pca)
print("WCSS After PCA:", kmeans_after_pca)


print("Running Spectral Clustering...")
spectral = SpectralClustering(n_clusters=10, affinity='nearest_neighbors', random_state=42)
y_spectral = spectral.fit_predict(X_mnist_pca)
print("Spectral Clustering Completed.")
